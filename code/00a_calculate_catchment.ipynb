# %%
# setup
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import requests
import calendar
import geopandas as gpd
import os.path as os
import scipy.stats
import seaborn.palettes
import seaborn.utils
import sys
from census import Census
from us import states
import http.client, urllib.request, urllib.parse, urllib.error, base64
import config

root= r"C:/Users/Jennah/Desktop/Code/machine-learning-final"
inp= os.join(root, "data", "1_raw")
out= os.join(root, "data", "2_intermediate")

# %%
import psycopg2 as psy
# load furman db
connection = psy.connect(
    host="",
    port=,
    user = "",
    password = ,
    database = )
cursor = connection.cursor()

# %%
## load pluto data as points
pluto= gpd.GeoDataFrame.from_postgis("""SELECT bbl, 
                                               tract2010,
                                               geom_point FROM mappluto_21v3
                                        WHERE landuse IN ('01', '02', '03', '04')""", connection,
                                    geom_col = "geom_point")

# %%
from pydrive.auth import GoogleAuth

gauth = GoogleAuth()
gauth.LocalWebserverAuth() # Creates local webserver and auto handles authentication.
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=570719947456-53haph7mjc317oel1ujh0kmjbfd499jf.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %%
from pydrive.drive import GoogleDrive
drive = GoogleDrive(gauth)
fileList = drive.ListFile({'q': "'1kiYbPtSYavHQKzyMWtXaLhP-JM2toXRm' in parents and trashed=false"}).GetList()
for file in fileList:
  print('Title: %s, ID: %s' % (file['title'], file['id']))
  # Get the folder ID that you want
  if(file['title'] == "To Share"):
      fileID = file['id']
# Out:
# Title: weighted_borobox.csv, ID: 1H8yM7UH14YdMqi5ASjHMd_dwA4C7-lKe
# Title: acs_2019_fuel_mobility.csv, ID: 1w3TaiypzzVSIYD9VvhCqwXaNfzkpj9V1
# Title: acs_2009_2019.csv, ID: 17PvjIPesTzugausfzMi7rTiXahTiHaH1
# Title: acs_2019only.csv, ID: 1z3-YL8loRQf9Qi6qSQUSwF8Wnwo-YQ5d
# Title: pluto_df.csv, ID: 1j2KR6Tpa4CTA0k1omVfE52UYlMBMz17o
# Title: hpd_agg_final.csv, ID: 1nIQD_4GDpg5ldTGgE5XqfiD11mxjrvEH
# Title: ct_box_xwalk.csv, ID: 1nW-ODlhdUFKhTYzHZQOu3CCZN87oYXel
# Title: fire_box_sum.csv, ID: 1zYSWlWtgNWsruaEkSSCqyXHIIdq7BEAP
# Title: census_acs, ID: 1DjJ3pOLAo4MOpgmeNPSXJbRzF_S10fDM
# Title: hpd_per_bbl.csv, ID: 1xXilfI1zEmyEYE_TtMdawcnmnZlTv__Z
# Title: hpd_2012_2022_v3.csv, ID: 1HXst8E2ZuPVKvKe_9jmSQwKYppOJjraD
# Title: pluto_borobox.csv, ID: 1Yf4xIIOBmKU2WIlImat8qaN3z2L239Nw
# Title: fire_dispatch_tracts.csv, ID: 1psGrpBmGmNHPwM4lsRyiDX9tX5cf_UsO
# Title: pluto_borobox.geojson, ID: 1UGelHNCzfSwsvbqBzyBX5GkrY_PmPGdp
# Title: fire_dispatch.csv, ID: 1ulJlwpaezzq_aYV6jZzRWpmXLVlpO8qu
# Title: dev_permits.csv, ID: 1mH_X0bLa_a1r-hpzwz43HpC7fFcayufp
# Title: all_vacate.csv, ID: 1WfnTEjOaDNEb3E2vurXS_XkxJ0J1isdN
# Title: pluto_ct.csv, ID: 1ZLZZS79fi4Z0RFTNMRO6GfkNwughRuej
# Title: ll84_avgenergy.csv, ID: 1NOKtbGyL3_TBSMp_eqybVaQc67t33yuo
# Title: fire_vacate.csv, ID: 11LV7007TbrVlfilkSvslDewQRZ9m0F-A
# Title: speculation_hpd.csv, ID: 1yf86QR6yv2Z9Q6WNINW87RASUsdHPDl6
# Title: fire_tract_sum.csv, ID: 16PukYkHO7Fgtbx26vdfG2sdUfDGreUnq
# Title: fire_vacate_bbl.csv, ID: 1caDnIMowquAoJuZi1tDlyEqAS4HhXiU0
# Title: dob_2012_2022_v2.csv, ID: 1jZoaDMOWDgZZYdDZBIVPjElNhlvwx3IC
# Title: dob_2012_2022.csv, ID: 1vBwNTewjAQcDOLDWIh8ZYerUJRLYKqFs

# %% [markdown]
# ## Calculate catchment for alarm boxes

# %%
firecomp= gpd.read_file("https://services5.arcgis.com/GfwWNkhOj9bNBqoJ/arcgis/rest/services/NYC_Fire_Companies/FeatureServer/0/query?where=1=1&outFields=*&outSR=4326&f=pgeojson")
firecomp

firebat= gpd.read_file("https://services5.arcgis.com/GfwWNkhOj9bNBqoJ/arcgis/rest/services/NYC_Fire_Battalions/FeatureServer/0/query?where=1=1&outFields=*&outSR=4326&f=pgeojson")
firebat

firediv= gpd.read_file("https://services5.arcgis.com/GfwWNkhOj9bNBqoJ/arcgis/rest/services/NYC_Fire_Divisions/FeatureServer/0/query?where=1=1&outFields=*&outSR=4326&f=pgeojson")
firediv
# Out:
#    OBJECTID  FireDiv   Shape__Area  Shape__Length  \
# 0         1        7  9.155053e+08  475522.142626
# 1         2        3  3.096170e+08  140949.248366
# 2         3        1  1.867217e+08  129804.513187
# 3         4       15  9.892598e+08  467217.078989
# 4         5       11  4.943151e+08  256156.400198
# 5         6       13  1.496042e+09  686533.872602
# 6         7       14  1.562116e+09  456750.206166
# 7         8        8  2.063724e+09  623169.698977
# 8         9        6  3.731799e+08  182950.385141
#
#                                             geometry
# 0  MULTIPOLYGON (((-73.78922 40.85875, -73.78919 ...
# 1  MULTIPOLYGON (((-73.92134 40.80086, -73.92114 ...
# 2  MULTIPOLYGON (((-74.04398 40.68859, -74.04439 ...
# 3  MULTIPOLYGON (((-73.86328 40.58389, -73.86381 ...
# 4  POLYGON ((-73.95440 40.73912, -73.95428 40.739...
# 5  MULTIPOLYGON (((-73.83193 40.59346, -73.83117 ...
# 6  MULTIPOLYGON (((-73.94180 40.76906, -73.94257 ...
# 7  MULTIPOLYGON (((-74.20313 40.57961, -74.20302 ...
# 8  MULTIPOLYGON (((-73.93516 40.83269, -73.93513 ...

# %%
fig, ax = plt.subplots(figsize=(8, 8))
firebat.plot(ax=ax, color='#6a6a6a', edgecolor='white', linewidth=2)
firediv.plot(ax=ax, color='none', edgecolor='red')
# Out:
# <AxesSubplot:>

# %%
firevac= pd.read_csv("https://data.cityofnewyork.us/resource/n5xc-7jfa.csv?$limit=100000")
firevac.shape
# Out:
# (93, 19)

# %%
alarmbox= gpd.read_file("https://data.cityofnewyork.us/resource/v57i-gtxb.geojson?$limit=100000").to_crs(2263)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
firebat.to_crs(2263).plot(ax=ax, color='#6a6a6a', edgecolor='white', linewidth=2)
firediv.to_crs(2263).plot(ax=ax, color='none', edgecolor='red')
alarmbox.plot(ax=ax, color='green', markersize=0.5, alpha = 0.8)
# Out:
# <AxesSubplot:>

# %%
pluto.head()
#alarmbox
# Out:
#           bbl tract2010                      geom_point
# 0  1009270035      0064   POINT (989840.890 207538.615)
# 1  1009270036      0064   POINT (989820.742 207549.753)
# 2  1021800078      0273  POINT (1001681.719 249321.912)
# 3  2035620129      0016  POINT (1023205.848 237638.715)
# 4  2045730032      0340  POINT (1022524.360 256662.228)

# %%
from scipy.spatial import cKDTree
from shapely.geometry import Point

def ckdnearest(gdA, gdB):
    # vectorized function from https://gis.stackexchange.com/questions/222315/finding-nearest-point-in-other-geodataframe-using-geopandas
    nA = np.array(list(gdA.geometry.apply(lambda x: (x.x, x.y))))
    nB = np.array(list(gdB.geometry.apply(lambda x: (x.x, x.y))))
    btree = cKDTree(nB)
    dist, idx = btree.query(nA, k=1)
    gdB_nearest = gdB.iloc[idx].drop(columns="geometry").reset_index(drop=True)
    gdf = pd.concat(
        [
            gdA.reset_index(drop=True),
            gdB_nearest,
            pd.Series(dist, name='dist')
        ], 
        axis=1)

    return gdf

pluto_borobox= ckdnearest(pluto, alarmbox)

# %%
pluto_borobox.head()
# Out:
#           bbl tract2010                      geom_point  \
# 0  1009270035      0064   POINT (989840.890 207538.615)
# 1  1009270036      0064   POINT (989820.742 207549.753)
# 2  1021800078      0273  POINT (1001681.719 249321.912)
# 3  2035620129      0016  POINT (1023205.848 237638.715)
# 4  2045730032      0340  POINT (1022524.360 256662.228)
#
#                           location     latitude    zip borobox  \
# 0                  1 AVE & E 20 ST   40.7349341  10009   M0493
# 1                  1 AVE & E 20 ST   40.7349341  10009   M0493
# 2           BENNETT AVE & W 181 ST  40.85044733  10033   M1740
# 3  SEWARD AVE S OF WHITE PLAINS RD  40.81968033  10473   X2672
# 4        BURKE AVE & BRONXWOOD AVE  40.87133651  10469   X3491
#
#   communitydistict     longitude box_type citycouncil    borough        dist
# 0             MN06  -73.97981004      ERS           2  Manhattan  505.090285
# 1             MN06  -73.97981004      ERS           2  Manhattan  516.794735
# 2             MN12  -73.93666143      ERS          10  Manhattan  217.283516
# 3             BX09   -73.8578688      ERS          18      Bronx  488.252822
# 4             BX12  -73.86137924      ERS          12      Bronx  116.232575

# %%
pluto_borobox.to_csv(os.join(out, "pluto_borobox.csv"))
#pluto_borobox.to_file(os.join(out, "pluto_borobox.geojson"), driver = "GeoJSON")

# %% [markdown]
# ### Load building alarmbox data
# __For visualization:__
# * Create convex hull

# %%
pluto_borobox= gpd.read_file(os.join(out, "pluto_borobox.geojson"), driver = "GeoJSON")

# %%
## create map
fig, ax = plt.subplots(figsize=(20, 10))
alarmbox_crop.plot(ax=ax, color = 'red')
pluto_borobox[pluto_borobox['borobox'].isin(alarmbox_crop['borobox'].tolist())]\
        .reset_index().plot(column="borobox", ax=ax)
plt.axis('off');
plt.savefig('assigned_points_firebox.pdf')

# %%
d_convex_hull= pluto_borobox.dissolve("borobox").convex_hull.reset_index().set_geometry(0)
d_convex_hull.head()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
d_convex_hull.set_crs(2263).plot(ax=ax, column = 'borobox')
# Out:
# <AxesSubplot:>

# %%
d_convex_hull.to_file(os.join(out, "borobox_convex_hull.geojson"), driver = "GeoJSON")

# %% [markdown]
# ## Create Census Tract Weights

# %%
pluto_borobox = gpd.read_file(os.join(out, "pluto_borobox.geojson"))

# %%
plutobox_ct= pd.merge(pluto_borobox.loc[:, ["bbl", "location", "borobox", "box_type", "latitude", "longitude"]],
         pluto.loc[:, ["bbl", "tract2010"]], on = "bbl")

plutobox_ct['boroct2010']= plutobox_ct['bbl'].str[0] + plutobox_ct['tract2010'].astype(str).str.replace(".", "", regex = False).str.pad(width = 6, side = "right",
                                                                                                                      fillchar = "0")
plutobox_ct.head()

# manual recode of borobox tract values
plutobox_ct.loc[plutobox_ct["borobox"]=="X4609", 'boroct2010']= '2027402'
plutobox_ct.loc[plutobox_ct["borobox"]=="Q1605", 'boroct2010']= '4107201'
plutobox_ct.loc[plutobox_ct["borobox"]=="Q2058", 'boroct2010']= '4088400'
plutobox_ct.loc[plutobox_ct["borobox"]=="R3845", 'boroct2010']= '5015603'
plutobox_ct.loc[plutobox_ct["borobox"]=="R4515", 'boroct2010']= '5024800'

# %%
# load acs data (to check census tract recoding)
csv = drive.CreateFile({'id': '17PvjIPesTzugausfzMi7rTiXahTiHaH1'})
csv.GetContentFile('acs_data.csv')  

acs= pd.read_csv('acs_data.csv').drop(['Unnamed: 0', 'Unnamed: 0.1'], axis = 1)
acs= acs.loc[acs['year']==2019]
acs.head()
# Out:
#            geofips  totpop    popdens  areasqmile  males  females  pop18under  \
# 21721  36005000100    6864  10599.550    0.647574   6345      519         103
# 21722  36005000200    4532  24481.190    0.185122   2193     2339        1134
# 21723  36005000400    5516  18537.140    0.297565   2810     2706        1071
# 21724  36005001600    5825  31101.490    0.187290   2422     3403        1546
# 21725  36005001900    3141   4877.152    0.644023   1583     1558         898
#
#        pop18_34  pop35_64  pop65plus  ...  pctnhblack  pctnhaian  pctnhasian  \
# 21721      3322      3392         47  ...   52.462121   0.262238    2.636946
# 21722       862      1605        931  ...   20.300088   0.000000    1.654898
# 21723      1319      2362        764  ...   22.915156   0.000000    2.193619
# 21724      1399      1978        902  ...   34.695279   0.000000    1.098712
# 21725      1052      1111         80  ...   29.831264   0.000000    2.292264
#
#        pctnhhawainpi  pctnhother  pctnhtwoplus  pctownerocch  pctrentocch  \
# 21721            0.0    0.276807      0.509907           NaN          NaN
# 21722            0.0    1.323919      0.000000     52.459016    47.540984
# 21723            0.0    0.163162      1.341552     79.040157    20.959843
# 21724            0.0    0.858369      0.429185     12.430238    87.569762
# 21725            0.0    0.700414      1.782872     10.565338    89.434662
#
#         crowding  crowdingrenter
# 21721        NaN             NaN
# 21722  11.997019       18.181818
# 21723   1.860921        4.906542
# 21724  11.415525       12.514484
# 21725   9.638554       10.777202
#
# [5 rows x 52 columns]

# %%
acs['geofips_recode']= acs['geofips'].astype(str).str[2:]
acs['geofips_recode']= np.select([acs['geofips_recode'].str[0:3] == '005',
                                 acs['geofips_recode'].str[0:3] == '047',
                                 acs['geofips_recode'].str[0:3] == '061',
                                 acs['geofips_recode'].str[0:3] == '081',
                                 acs['geofips_recode'].str[0:3] == '085'],
                                ['2' + acs['geofips_recode'].str[3:],
                                '3' + acs['geofips_recode'].str[3:],
                                 '1' + acs['geofips_recode'].str[3:],
                                 '4' + acs['geofips_recode'].str[3:],
                                 '5' + acs['geofips_recode'].str[3:]])

print(acs.loc[acs['geofips_recode'].str.len() < 7, 'geofips_recode'].head())
acs.loc[acs['geofips_recode'].str.len() < 7, 'geofips_recode']= \
acs.loc[acs['geofips_recode'].str.len() < 7, 'geofips_recode'].str.pad(width = 7, fillchar = "0", side = "right")

acs[['geofips_recode', 'geofips']]
# Out:
# Series([], Name: geofips_recode, dtype: object)
#       geofips_recode      geofips
# 21721        2000100  36005000100
# 21722        2000200  36005000200
# 21723        2000400  36005000400
# 21724        2001600  36005001600
# 21725        2001900  36005001900
# ...              ...          ...
# 23883        5030302  36085030302
# 23884        5031901  36085031901
# 23885        5031902  36085031902
# 23886        5032300  36085032300
# 23887        5990100  36085990100
#
# [2167 rows x 2 columns]

# %%
acs.loc[(acs['geofips'].astype(str) == '36047033600'), :]
# Out:
#            geofips  totpop   popdens  areasqmile  males  females  pop18under  \
# 22340  36047033600    4443  16720.04    0.265729   2185     2258         839
#
#        pop18_34  pop35_64  pop65plus  ...  pctnhaian  pctnhasian  \
# 22340       749      2109        746  ...        0.0    7.089804
#
#        pctnhhawainpi  pctnhother  pctnhtwoplus  pctownerocch  pctrentocch  \
# 22340            0.0         0.0      2.025658     49.618321    50.381679
#
#        crowding  crowdingrenter  geofips_recode
# 22340  4.898219        5.808081         3033600
#
# [1 rows x 53 columns]

# %%
# this is not true
# assert (acs["geofips"].str.len() == 9).all()
assert (acs["geofips_recode"].str.len() == 7).all()
print(acs.loc[acs["geofips"].astype(str).str.len() != 9].shape[0])
acs.loc[acs["geofips"].astype(str).str.len() != 9].head()
# Out:
# 2167
#            geofips  totpop    popdens  areasqmile  males  females  pop18under  \
# 21721  36005000100    6864  10599.550    0.647574   6345      519         103
# 21722  36005000200    4532  24481.190    0.185122   2193     2339        1134
# 21723  36005000400    5516  18537.140    0.297565   2810     2706        1071
# 21724  36005001600    5825  31101.490    0.187290   2422     3403        1546
# 21725  36005001900    3141   4877.152    0.644023   1583     1558         898
#
#        pop18_34  pop35_64  pop65plus  ...  pctnhaian  pctnhasian  \
# 21721      3322      3392         47  ...   0.262238    2.636946
# 21722       862      1605        931  ...   0.000000    1.654898
# 21723      1319      2362        764  ...   0.000000    2.193619
# 21724      1399      1978        902  ...   0.000000    1.098712
# 21725      1052      1111         80  ...   0.000000    2.292264
#
#        pctnhhawainpi  pctnhother  pctnhtwoplus  pctownerocch  pctrentocch  \
# 21721            0.0    0.276807      0.509907           NaN          NaN
# 21722            0.0    1.323919      0.000000     52.459016    47.540984
# 21723            0.0    0.163162      1.341552     79.040157    20.959843
# 21724            0.0    0.858369      0.429185     12.430238    87.569762
# 21725            0.0    0.700414      1.782872     10.565338    89.434662
#
#         crowding  crowdingrenter  geofips_recode
# 21721        NaN             NaN         2000100
# 21722  11.997019       18.181818         2000200
# 21723   1.860921        4.906542         2000400
# 21724  11.415525       12.514484         2001600
# 21725   9.638554       10.777202         2001900
#
# [5 rows x 53 columns]

# %%
# merge pluto (w/ borobox and census tract to ACS data with recoded geofips var)
pluto_acs= plutobox_ct.merge(acs, left_on = "boroct2010", right_on = "geofips_recode", 
                             how = "outer",
                             indicator = True)
pluto_acs.head()
# Out:
#           bbl                  location borobox box_type     latitude  \
# 0  3042270037  BELMONT AVE & MILFORD ST   B1826      ERS  40.67338539
# 1  3040220001  BELMONT AVE & ATKINS AVE   B1804      ERS  40.67311965
# 2  3040220005  BELMONT AVE & ATKINS AVE   B1804      ERS  40.67311965
# 3  3040220006  BELMONT AVE & ATKINS AVE   B1804      ERS  40.67311965
# 4  3040220119  PITKIN AVE & BERRIMAN ST   B1824      ERS  40.67425552
#
#       longitude tract2010 boroct2010      geofips  totpop  ...  pctnhasian  \
# 0  -73.87680041      1194    3119400  36047119400    4892  ...    1.287817
# 1  -73.87864502      1194    3119400  36047119400    4892  ...    1.287817
# 2  -73.87864502      1194    3119400  36047119400    4892  ...    1.287817
# 3  -73.87864502      1194    3119400  36047119400    4892  ...    1.287817
# 4   -73.8798826      1194    3119400  36047119400    4892  ...    1.287817
#
#    pctnhhawainpi  pctnhother  pctnhtwoplus  pctownerocch  pctrentocch  \
# 0            0.0         0.0           0.0     31.165919    68.834081
# 1            0.0         0.0           0.0     31.165919    68.834081
# 2            0.0         0.0           0.0     31.165919    68.834081
# 3            0.0         0.0           0.0     31.165919    68.834081
# 4            0.0         0.0           0.0     31.165919    68.834081
#
#     crowding  crowdingrenter  geofips_recode  _merge
# 0  33.781764       44.082519         3119400    both
# 1  33.781764       44.082519         3119400    both
# 2  33.781764       44.082519         3119400    both
# 3  33.781764       44.082519         3119400    both
# 4  33.781764       44.082519         3119400    both
#
# [5 rows x 62 columns]

# %%
# check merge results
pluto_acs["_merge"].value_counts()
# Out:
# both          764560
# right_only        57
# left_only          0
# Name: _merge, dtype: int64

# %%
pluto_acs.loc[pluto_acs["_merge"]=="right_only", "geofips_recode"].value_counts()
# note: bronx tract 001 is Rikers Island
# i think these are ok, spot checked some--many seem like parks
# top two with population seem like rikers and part of roosevelt island?
pluto_acs.loc[pluto_acs["_merge"]=="right_only", :].sort_values('totpop', ascending = False)
# Out:
#         bbl location borobox box_type latitude longitude tract2010 boroct2010  \
# 764560  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764585  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764586  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764565  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764614  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764598  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764561  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764590  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764612  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764576  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764587  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764599  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764566  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764600  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764569  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764584  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764574  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764583  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764601  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764597  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764605  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764602  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764603  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764604  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764595  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764606  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764607  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764608  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764609  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764610  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764611  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764613  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764615  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764596  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764588  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764594  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764593  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764562  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764563  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764564  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764567  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764568  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764570  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764571  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764572  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764573  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764575  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764577  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764578  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764579  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764580  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764581  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764582  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764589  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764591  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764592  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
# 764616  NaN      NaN     NaN      NaN      NaN       NaN       NaN        NaN
#
#             geofips  totpop  ...  pctnhasian  pctnhhawainpi  pctnhother  \
# 764560  36005000100    6864  ...    2.636946       0.000000    0.276807
# 764585  36061023802    6086  ...   26.043378       0.000000    0.000000
# 764586  36061024000    2009  ...    3.135889       1.095072    0.000000
# 764565  36005031900     633  ...    6.003160       0.000000    0.000000
# 764614  36085001800     588  ...    3.061224       0.000000    1.020408
# 764598  36081042600     477  ...    6.079665       0.000000    0.000000
# 764561  36005002400     155  ...    0.000000       0.000000    0.000000
# 764590  36081005000      49  ...    0.000000       0.000000    0.000000
# 764612  36081138502      39  ...    0.000000       0.000000    0.000000
# 764576  36047085200      26  ...    0.000000       0.000000    0.000000
# 764587  36061029700      22  ...    9.090909       0.000000    0.000000
# 764599  36081056100      17  ...   47.058824       0.000000    0.000000
# 764566  36005033400      15  ...    0.000000       0.000000    0.000000
# 764600  36081060701      14  ...    0.000000       0.000000    0.000000
# 764569  36047015400      11  ...    0.000000       0.000000    0.000000
# 764584  36061021703      11  ...    0.000000       0.000000    0.000000
# 764574  36047070202       8  ...    0.000000       0.000000    0.000000
# 764583  36061014300       2  ...    0.000000       0.000000    0.000000
# 764601  36081061302       0  ...         NaN            NaN         NaN
# 764597  36081038302       0  ...         NaN            NaN         NaN
# 764605  36081071600       0  ...         NaN            NaN         NaN
# 764602  36081062400       0  ...         NaN            NaN         NaN
# 764603  36081064102       0  ...         NaN            NaN         NaN
# 764604  36081065501       0  ...         NaN            NaN         NaN
# 764595  36081029900       0  ...         NaN            NaN         NaN
# 764606  36081079300       0  ...         NaN            NaN         NaN
# 764607  36081091602       0  ...         NaN            NaN         NaN
# 764608  36081099900       0  ...         NaN            NaN         NaN
# 764609  36081107202       0  ...         NaN            NaN         NaN
# 764610  36081121100       0  ...         NaN            NaN         NaN
# 764611  36081128300       0  ...         NaN            NaN         NaN
# 764613  36081990100       0  ...         NaN            NaN         NaN
# 764615  36085015400       0  ...         NaN            NaN         NaN
# 764596  36081033100       0  ...         NaN            NaN         NaN
# 764588  36061031100       0  ...         NaN            NaN         NaN
# 764594  36081024600       0  ...         NaN            NaN         NaN
# 764593  36081022900       0  ...         NaN            NaN         NaN
# 764562  36005016300       0  ...         NaN            NaN         NaN
# 764563  36005017100       0  ...         NaN            NaN         NaN
# 764564  36005024900       0  ...         NaN            NaN         NaN
# 764567  36005050400       0  ...         NaN            NaN         NaN
# 764568  36047008600       0  ...         NaN            NaN         NaN
# 764570  36047017500       0  ...         NaN            NaN         NaN
# 764571  36047017700       0  ...         NaN            NaN         NaN
# 764572  36047040700       0  ...         NaN            NaN         NaN
# 764573  36047066600       0  ...         NaN            NaN         NaN
# 764575  36047070203       0  ...         NaN            NaN         NaN
# 764577  36047096000       0  ...         NaN            NaN         NaN
# 764578  36047118000       0  ...         NaN            NaN         NaN
# 764579  36047990100       0  ...         NaN            NaN         NaN
# 764580  36061000100       0  ...         NaN            NaN         NaN
# 764581  36061000500       0  ...         NaN            NaN         NaN
# 764582  36061008602       0  ...         NaN            NaN         NaN
# 764589  36061031900       0  ...         NaN            NaN         NaN
# 764591  36081009900       0  ...         NaN            NaN         NaN
# 764592  36081010701       0  ...         NaN            NaN         NaN
# 764616  36085990100       0  ...         NaN            NaN         NaN
#
#         pctnhtwoplus  pctownerocch  pctrentocch  crowding  crowdingrenter  \
# 764560      0.509907           NaN          NaN       NaN             NaN
# 764585      2.678278      4.954955    95.045045  9.966216       10.189573
# 764586      0.497760           NaN          NaN       NaN             NaN
# 764565      1.737757           NaN          NaN       NaN             NaN
# 764614      5.782313      2.209945    97.790055  8.287293        8.474576
# 764598      0.000000           NaN          NaN       NaN             NaN
# 764561      0.000000      0.000000   100.000000  0.000000        0.000000
# 764590      0.000000     32.258065    67.741935  0.000000        0.000000
# 764612      0.000000           NaN          NaN       NaN             NaN
# 764576      0.000000    100.000000     0.000000  0.000000             NaN
# 764587      0.000000           NaN          NaN       NaN             NaN
# 764599      0.000000     50.000000    50.000000  0.000000        0.000000
# 764566      0.000000    100.000000     0.000000  0.000000             NaN
# 764600      0.000000    100.000000     0.000000  0.000000             NaN
# 764569      0.000000    100.000000     0.000000  0.000000             NaN
# 764584      0.000000    100.000000     0.000000  0.000000             NaN
# 764574      0.000000      0.000000   100.000000  0.000000        0.000000
# 764583      0.000000           NaN          NaN       NaN             NaN
# 764601           NaN           NaN          NaN       NaN             NaN
# 764597           NaN           NaN          NaN       NaN             NaN
# 764605           NaN           NaN          NaN       NaN             NaN
# 764602           NaN           NaN          NaN       NaN             NaN
# 764603           NaN           NaN          NaN       NaN             NaN
# 764604           NaN           NaN          NaN       NaN             NaN
# 764595           NaN           NaN          NaN       NaN             NaN
# 764606           NaN           NaN          NaN       NaN             NaN
# 764607           NaN           NaN          NaN       NaN             NaN
# 764608           NaN           NaN          NaN       NaN             NaN
# 764609           NaN           NaN          NaN       NaN             NaN
# 764610           NaN           NaN          NaN       NaN             NaN
# 764611           NaN           NaN          NaN       NaN             NaN
# 764613           NaN           NaN          NaN       NaN             NaN
# 764615           NaN           NaN          NaN       NaN             NaN
# 764596           NaN           NaN          NaN       NaN             NaN
# 764588           NaN           NaN          NaN       NaN             NaN
# 764594           NaN           NaN          NaN       NaN             NaN
# 764593           NaN           NaN          NaN       NaN             NaN
# 764562           NaN           NaN          NaN       NaN             NaN
# 764563           NaN           NaN          NaN       NaN             NaN
# 764564           NaN           NaN          NaN       NaN             NaN
# 764567           NaN           NaN          NaN       NaN             NaN
# 764568           NaN           NaN          NaN       NaN             NaN
# 764570           NaN           NaN          NaN       NaN             NaN
# 764571           NaN           NaN          NaN       NaN             NaN
# 764572           NaN           NaN          NaN       NaN             NaN
# 764573           NaN           NaN          NaN       NaN             NaN
# 764575           NaN           NaN          NaN       NaN             NaN
# 764577           NaN           NaN          NaN       NaN             NaN
# 764578           NaN           NaN          NaN       NaN             NaN
# 764579           NaN           NaN          NaN       NaN             NaN
# 764580           NaN           NaN          NaN       NaN             NaN
# 764581           NaN           NaN          NaN       NaN             NaN
# 764582           NaN           NaN          NaN       NaN             NaN
# 764589           NaN           NaN          NaN       NaN             NaN
# 764591           NaN           NaN          NaN       NaN             NaN
# 764592           NaN           NaN          NaN       NaN             NaN
# 764616           NaN           NaN          NaN       NaN             NaN
#
#         geofips_recode      _merge
# 764560         2000100  right_only
# 764585         1023802  right_only
# 764586         1024000  right_only
# 764565         2031900  right_only
# 764614         5001800  right_only
# 764598         4042600  right_only
# 764561         2002400  right_only
# 764590         4005000  right_only
# 764612         4138502  right_only
# 764576         3085200  right_only
# 764587         1029700  right_only
# 764599         4056100  right_only
# 764566         2033400  right_only
# 764600         4060701  right_only
# 764569         3015400  right_only
# 764584         1021703  right_only
# 764574         3070202  right_only
# 764583         1014300  right_only
# 764601         4061302  right_only
# 764597         4038302  right_only
# 764605         4071600  right_only
# 764602         4062400  right_only
# 764603         4064102  right_only
# 764604         4065501  right_only
# 764595         4029900  right_only
# 764606         4079300  right_only
# 764607         4091602  right_only
# 764608         4099900  right_only
# 764609         4107202  right_only
# 764610         4121100  right_only
# 764611         4128300  right_only
# 764613         4990100  right_only
# 764615         5015400  right_only
# 764596         4033100  right_only
# 764588         1031100  right_only
# 764594         4024600  right_only
# 764593         4022900  right_only
# 764562         2016300  right_only
# 764563         2017100  right_only
# 764564         2024900  right_only
# 764567         2050400  right_only
# 764568         3008600  right_only
# 764570         3017500  right_only
# 764571         3017700  right_only
# 764572         3040700  right_only
# 764573         3066600  right_only
# 764575         3070203  right_only
# 764577         3096000  right_only
# 764578         3118000  right_only
# 764579         3990100  right_only
# 764580         1000100  right_only
# 764581         1000500  right_only
# 764582         1008602  right_only
# 764589         1031900  right_only
# 764591         4009900  right_only
# 764592         4010701  right_only
# 764616         5990100  right_only
#
# [57 rows x 62 columns]

# %%
# comparison census tracts, check it merges with comparison census tracts
ct_comp= pd.read_csv(os.join(inp, "NYC_Census_Tracts_for_2010_US_Census.csv"))
ct_comp["BoroCT2010"]= ct_comp["BoroCT2010"].astype(str)

ct_comp_merge= plutobox_ct.merge(ct_comp, left_on = "boroct2010", right_on = "BoroCT2010",
                                 how = "outer",
                                 indicator = True)
ct_comp.head()
ct_comp_merge["_merge"].value_counts()
# Out:
# both          764560
# right_only        55
# left_only          0
# Name: _merge, dtype: int64

# %% [markdown]
# ## Count of buildings by census tract

# %%
plutobox_ct_count= plutobox_ct.value_counts(['boroct2010', 'borobox']).rename('count').reset_index()
plutobox_ct_count
# Out:
#       boroct2010 borobox  count
# 0        3070201   B4116   1614
# 1        3033600   B3520    836
# 2        2051600   X4607    694
# 3        5020803   R4329    661
# 4        5017007   R3387    660
# ...          ...     ...    ...
# 18620    3031100   B0918      1
# 18621    3031300   B1579      1
# 18622    3031900   B1044      1
# 18623    3032500   B3762      1
# 18624    5032300   R1184      1
#
# [18625 rows x 3 columns]

# %%
plutobox_ct_count= pd.merge(plutobox_ct_count,
         plutobox_ct_count.groupby('boroct2010', as_index = False)["count"].sum()\
         .rename({'count':'total'}, axis = 1), on = "boroct2010")
plutobox_ct_count['wgt']= plutobox_ct_count['count'].div(plutobox_ct_count['total'])

# %%
plutobox_ct_count
# Out:
#       boroct2010 borobox  count  total       wgt
# 0        3070201   B4116   1614   1876  0.860341
# 1        3070201   B3994    228   1876  0.121535
# 2        3070201   B4103     34   1876  0.018124
# 3        3033600   B3520    836    913  0.915663
# 4        3033600   B3522     77    913  0.084337
# ...          ...     ...    ...    ...       ...
# 18620    3035000   B3564      1      2  0.500000
# 18621    3035601   B3387      1      1  1.000000
# 18622    3025500   B0365      1      2  0.500000
# 18623    3025500   B0368      1      2  0.500000
# 18624    3025902   B0364      1      1  1.000000
#
# [18625 rows x 5 columns]

# %%
## save census tract, borobox, weight crosswalk
plutobox_ct_count.to_csv(os.join(out, "ct_box_xwalk.csv"))
